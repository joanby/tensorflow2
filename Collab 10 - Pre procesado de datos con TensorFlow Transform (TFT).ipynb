# %% [markdown]
# <a href="https://colab.research.google.com/github/joanby/tensorflow2/blob/master/Collab%2010%20-%20Pre%20procesado%20de%20datos%20con%20TensorFlow%20Transform%20(TFT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Paso 1: Instalar las dependencias y configurar el entorno

# %%
# !pip install -q --upgrade tensorflow-transform
# Out:
#      |████████████████████████████████| 378kB 2.8MB/s
#      |████████████████████████████████| 1.8MB 13.2MB/s
#      |████████████████████████████████| 8.6MB 5.6MB/s
#      |████████████████████████████████| 63.8MB 47kB/s
#      |████████████████████████████████| 51kB 6.1MB/s
#      |████████████████████████████████| 1.4MB 50.4MB/s
#      |████████████████████████████████| 61kB 8.4MB/s
#      |████████████████████████████████| 71kB 10.7MB/s
#      |████████████████████████████████| 81kB 11.0MB/s
#      |████████████████████████████████| 153kB 56.7MB/s
#      |████████████████████████████████| 829kB 55.6MB/s
#      |████████████████████████████████| 256kB 59.9MB/s
#      |████████████████████████████████| 153kB 62.1MB/s
#      |████████████████████████████████| 440kB 52.6MB/s
#      |████████████████████████████████| 184kB 58.1MB/s
#      |████████████████████████████████| 276kB 55.8MB/s
#      |████████████████████████████████| 174kB 54.8MB/s
#      |████████████████████████████████| 122kB 58.6MB/s
#      |████████████████████████████████| 174kB 42.0MB/s
#      |████████████████████████████████| 92kB 11.6MB/s
#      |████████████████████████████████| 112kB 49.0MB/s
#      |████████████████████████████████| 1.2MB 52.5MB/s
#      |████████████████████████████████| 266kB 55.0MB/s
#      |████████████████████████████████| 153kB 57.0MB/s
#   Building wheel for hdfs (setup.py) ... done
#   Building wheel for oauth2client (setup.py) ... done
#   Building wheel for dill (setup.py) ... done
#   Building wheel for future (setup.py) ... done
#   Building wheel for avro-python3 (setup.py) ... done
#   Building wheel for google-apitools (setup.py) ... done
#   Building wheel for grpc-google-iam-v1 (setup.py) ... done
#   Building wheel for idna-ssl (setup.py) ... done
# ERROR: pydrive 1.3.1 has requirement oauth2client>=4.0.0, but you'll have oauth2client 3.0.0 which is incompatible.
# ERROR: multiprocess 0.70.10 has requirement dill>=0.3.2, but you'll have dill 0.3.1.1 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.17.2, but you'll have google-auth 1.22.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.24.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: google-cloud-spanner 1.19.0 has requirement google-cloud-core<2.0dev,>=1.4.1, but you'll have google-cloud-core 1.0.3 which is incompatible.
# ERROR: google-cloud-bigtable 1.5.0 has requirement google-cloud-core<2.0dev,>=1.4.1, but you'll have google-cloud-core 1.0.3 which is incompatible.

# %%
import os
os.kill(os.getpid(), 9)

# %% [markdown]
# ## Paso 2: Importar las dependencias del proyecto

# %%
import tempfile
import pandas as pd
import tensorflow as tf
import tensorflow_transform as tft
import tensorflow_transform.beam.impl as tft_beam
from tensorflow_transform.tf_metadata import schema_utils

from __future__ import print_function
from tensorflow_transform.tf_metadata import dataset_metadata, dataset_schema

# %% [markdown]
# ## Paso 3: Pre procesado de datos

# %% [markdown]
# ### Cargar el dataset de polución

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/joanby/tensorflow2/master/datasets/pollution-small.csv")

# %%
dataset.head()
# Out:
#        Date   pm10    no2    so2   soot
# 0  1/1/2009  98.67  14.10  44.38  34.81
# 1  1/2/2009  52.33  14.10  29.75  33.06
# 2  1/3/2009  74.67  20.50  36.25  39.25
# 3  1/4/2009  72.00  17.30  46.44  34.38
# 4  1/5/2009  81.00  25.64  56.56  45.59

# %% [markdown]
# ### Eliminar la columna de la fecha

# %%
features = dataset.drop("Date", axis=1)

# %%
features.head()
# Out:
#     pm10    no2    so2   soot
# 0  98.67  14.10  44.38  34.81
# 1  52.33  14.10  29.75  33.06
# 2  74.67  20.50  36.25  39.25
# 3  72.00  17.30  46.44  34.38
# 4  81.00  25.64  56.56  45.59

# %% [markdown]
# ### Convertir el dataset de dataframe a lista de diccionarios de Python

# %%
dict_features = list(features.to_dict("index").values())

# %%
dict_features[:2]
# Out:
# [{'no2': 14.1, 'pm10': 98.67, 'so2': 44.38, 'soot': 34.81},
#  {'no2': 14.1, 'pm10': 52.33, 'so2': 29.75, 'soot': 33.06}]

# %% [markdown]
# ### Definir los metadatos del dataset

# %%
data_metadata = dataset_metadata.DatasetMetadata(
    schema_utils.schema_from_feature_spec({
        "no2":tf.io.FixedLenFeature([], tf.float32),
        "so2":tf.io.FixedLenFeature([], tf.float32),
        "pm10":tf.io.FixedLenFeature([], tf.float32),
        "soot":tf.io.FixedLenFeature([], tf.float32),
    }
    )
)

# %%
data_metadata
# Out:
# {'_schema': feature {
#   name: "no2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "pm10"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "so2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "soot"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# }

# %% [markdown]
# ## Paso 4:La función preprocessing

# %%
def preprocessing_fn(inputs):
    
    no2 = inputs['no2']
    pm10 = inputs['pm10']
    so2 = inputs['so2']
    soot = inputs['soot']
    
    no2_normalized = no2 - tft.mean(no2)
    so2_normalized = so2 - tft.mean(so2)
    
    pm10_normalized = tft.scale_to_0_1(pm10)
    soot_normalized = tft.scale_by_min_max(soot)
    
    return {
        "no2_normalized":no2_normalized,
        "so2_normalized":so2_normalized,
        "pm10_normalized":pm10_normalized,
        "soot_normalized":soot_normalized
    }

# %% [markdown]
# ## Paso 5: Pongámoslo todo a la vez
#
# Tensorflow Transform utiliza **Apache Beam** en segundo plano para llevar a cabo transformaciones de datos escalables. En esta función usaremos un ejecutor directo (direct runner).
#
# Argumentos para el ejector:
#
#     dict_features - Nuestro dataset convertido a diccionario de Python.
#     data_metadata - Los meta datos de nuestro dataset que hemos creado.
#     preprocessing_fn - La función de pre procesado principal. Se llamará para aplicar la operación de pre procesado columna a columna.
#
#
# El problema es que la sintaxis de Apache Beam es un poco especial. Se utiliza para apilar operaciones e invocar transformaciones en nuestros datos en formato de *pipe*.
#
# ```
# resultado = dato_a_pasar | donde_pasar_el_dato
# ```
#
# En nuestro caso sería algo como:
#
# **resultado**  -> `transformed_dataset, transform_fn`
#
# **dato_a_pasar** -> `(dict_features, data_metadata)`
#
# **donde_pasar_el_dato** -> `tft_beam.AnalyzeAndTransformDataset(preprocessing_fn)`
#
# ```
# transformed_dataset, transform_fn = ((dict_features, data_metadata) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))
#
# ```
#
# Si te interesa aprender más acerca de esta sintaxis, déjame que te recomende el siguiente link:
# https://beam.apache.org/documentation/programming-guide/#applying-transforms
#
# LINKS:
# > Mas acerca de Apache Beam: https://beam.apache.org/

# %%
def data_transform():
    
    with tft_beam.Context(temp_dir=tempfile.mkdtemp()):
        transformed_dataset, transform_fn = ((dict_features, data_metadata) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))
        
    transformed_data, transformed_metadata = transformed_dataset
    
    for i in range(len(transformed_data)):
        print("Raw: ", dict_features[i])
        print("Transformed:", transformed_data[i])

# %%
data_transform()
# Out:
# WARNING:tensorflow:Tensorflow version (2.3.0) found. Note that Tensorflow Transform support for TF 2.0 is currently in beta, and features such as tf.function may not work as intended.
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:tensorflow:Tensorflow version (2.3.0) found. Note that Tensorflow Transform support for TF 2.0 is currently in beta, and features such as tf.function may not work as intended.
# WARNING:tensorflow:Tensorflow version (2.3.0) found. Note that Tensorflow Transform support for TF 2.0 is currently in beta, and features such as tf.function may not work as intended.
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_transform/tf_utils.py:218: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_transform/tf_utils.py:218: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# WARNING:tensorflow:Issue encountered when serializing tft_analyzer_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# WARNING:tensorflow:Issue encountered when serializing tft_analyzer_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# WARNING:tensorflow:Issue encountered when serializing tft_mapper_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# WARNING:tensorflow:Issue encountered when serializing tft_mapper_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# INFO:tensorflow:SavedModel written to: /tmp/tmpjz2u8cqt/tftransform_tmp/a6bc5753a15b450c9de9fadfb8a9c07a/saved_model.pb
# INFO:tensorflow:SavedModel written to: /tmp/tmpjz2u8cqt/tftransform_tmp/a6bc5753a15b450c9de9fadfb8a9c07a/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# WARNING:tensorflow:Issue encountered when serializing tft_analyzer_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# WARNING:tensorflow:Issue encountered when serializing tft_analyzer_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# WARNING:tensorflow:Issue encountered when serializing tft_mapper_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# WARNING:tensorflow:Issue encountered when serializing tft_mapper_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# INFO:tensorflow:SavedModel written to: /tmp/tmpjz2u8cqt/tftransform_tmp/1d37ec4633bf459a81effd3b79a110d2/saved_model.pb
# INFO:tensorflow:SavedModel written to: /tmp/tmpjz2u8cqt/tftransform_tmp/1d37ec4633bf459a81effd3b79a110d2/saved_model.pb
# WARNING:tensorflow:Tensorflow version (2.3.0) found. Note that Tensorflow Transform support for TF 2.0 is currently in beta, and features such as tf.function may not work as intended.
# WARNING:tensorflow:Tensorflow version (2.3.0) found. Note that Tensorflow Transform support for TF 2.0 is currently in beta, and features such as tf.function may not work as intended.
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /tmp/tmpjz2u8cqt/tftransform_tmp/0c96a28531dc4796b077f44c881e80b6/saved_model.pb
# INFO:tensorflow:SavedModel written to: /tmp/tmpjz2u8cqt/tftransform_tmp/0c96a28531dc4796b077f44c881e80b6/saved_model.pb
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# Raw:  {'pm10': 98.67, 'no2': 14.1, 'so2': 44.38, 'soot': 34.81}
# Transformed: {'no2_normalized': -18.577978, 'pm10_normalized': 0.34071696, 'so2_normalized': 28.855408, 'soot_normalized': 0.2834235}
# Raw:  {'pm10': 52.33, 'no2': 14.1, 'so2': 29.75, 'soot': 33.06}
# Transformed: {'no2_normalized': -18.577978, 'pm10_normalized': 0.16963857, 'so2_normalized': 14.225407, 'soot_normalized': 0.26620758}
# Raw:  {'pm10': 74.67, 'no2': 20.5, 'so2': 36.25, 'soot': 39.25}
# Transformed: {'no2_normalized': -12.1779785, 'pm10_normalized': 0.25211355, 'so2_normalized': 20.725407, 'soot_normalized': 0.32710278}
# Raw:  {'pm10': 72.0, 'no2': 17.3, 'so2': 46.44, 'soot': 34.38}
# Transformed: {'no2_normalized': -15.377979, 'pm10_normalized': 0.24225645, 'so2_normalized': 30.915405, 'soot_normalized': 0.2791933}
# Raw:  {'pm10': 81.0, 'no2': 25.64, 'so2': 56.56, 'soot': 45.59}
# Transformed: {'no2_normalized': -7.037979, 'pm10_normalized': 0.2754827, 'so2_normalized': 41.035408, 'soot_normalized': 0.38947365}
# Raw:  {'pm10': 147.0, 'no2': 25.2, 'so2': 42.38, 'soot': 69.33}
# Transformed: {'no2_normalized': -7.4779778, 'pm10_normalized': 0.51914203, 'so2_normalized': 26.855408, 'soot_normalized': 0.6230202}
# Raw:  {'pm10': 185.0, 'no2': 21.91, 'so2': 71.69, 'soot': 84.06}
# Transformed: {'no2_normalized': -10.767979, 'pm10_normalized': 0.6594307, 'so2_normalized': 56.16541, 'soot_normalized': 0.7679291}
# Raw:  {'pm10': 148.67, 'no2': 25.09, 'so2': 51.75, 'soot': 74.41}
# Transformed: {'no2_normalized': -7.5879784, 'pm10_normalized': 0.5253073, 'so2_normalized': 36.225407, 'soot_normalized': 0.67299557}
# Raw:  {'pm10': 216.0, 'no2': 37.27, 'so2': 63.47, 'soot': 64.06}
# Transformed: {'no2_normalized': 4.592022, 'pm10_normalized': 0.7738767, 'so2_normalized': 47.945408, 'soot_normalized': 0.5711755}
# Raw:  {'pm10': 135.67, 'no2': 23.18, 'so2': 63.13, 'soot': 58.94}
# Transformed: {'no2_normalized': -9.497978, 'pm10_normalized': 0.47731382, 'so2_normalized': 47.605408, 'soot_normalized': 0.52080667}
# Raw:  {'pm10': 138.67, 'no2': 21.64, 'so2': 67.56, 'soot': 49.65}
# Transformed: {'no2_normalized': -11.037979, 'pm10_normalized': 0.48838922, 'so2_normalized': 52.035404, 'soot_normalized': 0.42941466}
# Raw:  {'pm10': 96.67, 'no2': 21.0, 'so2': 84.24, 'soot': 49.83}
# Transformed: {'no2_normalized': -11.6779785, 'pm10_normalized': 0.33333334, 'so2_normalized': 68.71541, 'soot_normalized': 0.43118542}
# Raw:  {'pm10': 101.0, 'no2': 22.64, 'so2': 83.06, 'soot': 46.44}
# Transformed: {'no2_normalized': -10.037979, 'pm10_normalized': 0.34931886, 'so2_normalized': 67.5354, 'soot_normalized': 0.39783567}
# Raw:  {'pm10': 129.33, 'no2': 25.42, 'so2': 78.11, 'soot': 55.53}
# Transformed: {'no2_normalized': -7.2579784, 'pm10_normalized': 0.4539078, 'so2_normalized': 62.585407, 'soot_normalized': 0.48726016}
# Raw:  {'pm10': 101.0, 'no2': 21.42, 'so2': 52.44, 'soot': 42.42}
# Transformed: {'no2_normalized': -11.257978, 'pm10_normalized': 0.34931886, 'so2_normalized': 36.915405, 'soot_normalized': 0.3582882}
# Raw:  {'pm10': 83.67, 'no2': 47.08, 'so2': 44.94, 'soot': 39.84}
# Transformed: {'no2_normalized': 14.402023, 'pm10_normalized': 0.28533983, 'so2_normalized': 29.415405, 'soot_normalized': 0.33290702}
# Raw:  {'pm10': 88.67, 'no2': 24.75, 'so2': 41.67, 'soot': 47.79}
# Transformed: {'no2_normalized': -7.9279785, 'pm10_normalized': 0.30379888, 'so2_normalized': 26.145405, 'soot_normalized': 0.41111657}
# Raw:  {'pm10': 149.33, 'no2': 34.75, 'so2': 87.22, 'soot': 83.79}
# Transformed: {'no2_normalized': 2.0720215, 'pm10_normalized': 0.52774394, 'so2_normalized': 71.695404, 'soot_normalized': 0.765273}
# Raw:  {'pm10': 41.0, 'no2': 32.08, 'so2': 52.89, 'soot': 46.42}
# Transformed: {'no2_normalized': -0.5979767, 'pm10_normalized': 0.12781039, 'so2_normalized': 37.365406, 'soot_normalized': 0.39763892}
# Raw:  {'pm10': 46.33, 'no2': 26.5, 'so2': 36.5, 'soot': 27.76}
# Transformed: {'no2_normalized': -6.1779785, 'pm10_normalized': 0.14748773, 'so2_normalized': 20.975407, 'soot_normalized': 0.21406788}
# Raw:  {'pm10': 26.67, 'no2': 19.67, 'so2': 28.59, 'soot': 16.28}
# Transformed: {'no2_normalized': -13.007978, 'pm10_normalized': 0.07490678, 'so2_normalized': 13.065407, 'soot_normalized': 0.101131335}
# Raw:  {'pm10': 28.33, 'no2': 23.42, 'so2': 19.82, 'soot': 18.17}
# Transformed: {'no2_normalized': -9.257978, 'pm10_normalized': 0.08103518, 'so2_normalized': 4.2954063, 'soot_normalized': 0.11972454}
# Raw:  {'pm10': 40.67, 'no2': 25.58, 'so2': 17.94, 'soot': 28.56}
# Transformed: {'no2_normalized': -7.0979786, 'pm10_normalized': 0.12659208, 'so2_normalized': 2.4154072, 'soot_normalized': 0.221938}
# Raw:  {'pm10': 38.0, 'no2': 30.33, 'so2': 19.88, 'soot': 27.39}
# Transformed: {'no2_normalized': -2.3479786, 'pm10_normalized': 0.11673496, 'so2_normalized': 4.355406, 'soot_normalized': 0.21042792}
# Raw:  {'pm10': 25.0, 'no2': 25.33, 'so2': 16.88, 'soot': 16.17}
# Transformed: {'no2_normalized': -7.3479786, 'pm10_normalized': 0.068741456, 'so2_normalized': 1.3554058, 'soot_normalized': 0.10004918}
# Raw:  {'pm10': 48.67, 'no2': 32.5, 'so2': 20.35, 'soot': 29.11}
# Transformed: {'no2_normalized': -0.17797852, 'pm10_normalized': 0.15612654, 'so2_normalized': 4.825407, 'soot_normalized': 0.22734874}
# Raw:  {'pm10': 35.67, 'no2': 27.42, 'so2': 25.47, 'soot': 22.28}
# Transformed: {'no2_normalized': -5.2579784, 'pm10_normalized': 0.10813304, 'so2_normalized': 9.945406, 'soot_normalized': 0.1601574}
# Raw:  {'pm10': 21.33, 'no2': 18.83, 'so2': 15.83, 'soot': 19.88}
# Transformed: {'no2_normalized': -13.847979, 'pm10_normalized': 0.055192526, 'so2_normalized': 0.30540657, 'soot_normalized': 0.13654695}
# Raw:  {'pm10': 16.67, 'no2': 17.5, 'so2': 14.44, 'soot': 23.71}
# Transformed: {'no2_normalized': -15.1779785, 'pm10_normalized': 0.037988704, 'so2_normalized': -1.0845938, 'soot_normalized': 0.17422526}
# Raw:  {'pm10': 29.33, 'no2': 15.42, 'so2': 15.28, 'soot': 27.61}
# Transformed: {'no2_normalized': -17.257978, 'pm10_normalized': 0.084727, 'so2_normalized': -0.24459362, 'soot_normalized': 0.21259221}
# Raw:  {'pm10': 31.33, 'no2': 17.0, 'so2': 17.39, 'soot': 24.33}
# Transformed: {'no2_normalized': -15.6779785, 'pm10_normalized': 0.09211061, 'so2_normalized': 1.865406, 'soot_normalized': 0.18032463}
# Raw:  {'pm10': 25.67, 'no2': 14.58, 'so2': 20.39, 'soot': 23.0}
# Transformed: {'no2_normalized': -18.097979, 'pm10_normalized': 0.071214974, 'so2_normalized': 4.865406, 'soot_normalized': 0.16724052}
# Raw:  {'pm10': 21.33, 'no2': 14.92, 'so2': 25.11, 'soot': 19.78}
# Transformed: {'no2_normalized': -17.757978, 'pm10_normalized': 0.055192526, 'so2_normalized': 9.585407, 'soot_normalized': 0.13556321}
# Raw:  {'pm10': 19.67, 'no2': 10.42, 'so2': 20.88, 'soot': 19.79}
# Transformed: {'no2_normalized': -22.257978, 'pm10_normalized': 0.049064126, 'so2_normalized': 5.355406, 'soot_normalized': 0.13566159}
# Raw:  {'pm10': 49.67, 'no2': 14.58, 'so2': 19.22, 'soot': 29.84}
# Transformed: {'no2_normalized': -18.097979, 'pm10_normalized': 0.15981835, 'so2_normalized': 3.695406, 'soot_normalized': 0.23453024}
# Raw:  {'pm10': 62.0, 'no2': 30.08, 'so2': 27.06, 'soot': 48.0}
# Transformed: {'no2_normalized': -2.5979786, 'pm10_normalized': 0.20533834, 'so2_normalized': 11.535406, 'soot_normalized': 0.41318247}
# Raw:  {'pm10': 30.67, 'no2': 27.67, 'so2': 21.61, 'soot': 35.68}
# Transformed: {'no2_normalized': -5.0079784, 'pm10_normalized': 0.08967402, 'so2_normalized': 6.0854073, 'soot_normalized': 0.29198226}
# Raw:  {'pm10': 29.33, 'no2': 19.58, 'so2': 16.39, 'soot': 23.11}
# Transformed: {'no2_normalized': -13.097979, 'pm10_normalized': 0.084727, 'so2_normalized': 0.86540604, 'soot_normalized': 0.16832267}
# Raw:  {'pm10': 27.0, 'no2': 16.17, 'so2': 15.11, 'soot': 23.79}
# Transformed: {'no2_normalized': -16.507978, 'pm10_normalized': 0.07612507, 'so2_normalized': -0.4145937, 'soot_normalized': 0.17501229}
# Raw:  {'pm10': 12.67, 'no2': 14.5, 'so2': 11.5, 'soot': 15.94}
# Transformed: {'no2_normalized': -18.177979, 'pm10_normalized': 0.02322147, 'so2_normalized': -4.0245934, 'soot_normalized': 0.097786516}
# Raw:  {'pm10': 30.33, 'no2': 25.0, 'so2': 17.67, 'soot': 30.05}
# Transformed: {'no2_normalized': -7.6779785, 'pm10_normalized': 0.088418804, 'so2_normalized': 2.1454067, 'soot_normalized': 0.23659614}
# Raw:  {'pm10': 22.0, 'no2': 21.0, 'so2': 15.56, 'soot': 24.05}
# Transformed: {'no2_normalized': -11.6779785, 'pm10_normalized': 0.057666037, 'so2_normalized': 0.035407066, 'soot_normalized': 0.17757007}
# Raw:  {'pm10': 18.33, 'no2': 17.82, 'so2': 14.33, 'soot': 17.21}
# Transformed: {'no2_normalized': -14.857979, 'pm10_normalized': 0.044117104, 'so2_normalized': -1.1945934, 'soot_normalized': 0.11028036}
# Raw:  {'pm10': 21.33, 'no2': 17.55, 'so2': 17.35, 'soot': 17.83}
# Transformed: {'no2_normalized': -15.127979, 'pm10_normalized': 0.055192526, 'so2_normalized': 1.825407, 'soot_normalized': 0.11637972}
# Raw:  {'pm10': 24.0, 'no2': 15.91, 'so2': 13.76, 'soot': 16.94}
# Transformed: {'no2_normalized': -16.767979, 'pm10_normalized': 0.06504965, 'so2_normalized': -1.7645931, 'soot_normalized': 0.1076242}
# Raw:  {'pm10': 18.67, 'no2': 12.91, 'so2': 13.35, 'soot': 14.89}
# Transformed: {'no2_normalized': -19.767979, 'pm10_normalized': 0.04537232, 'so2_normalized': -2.174593, 'soot_normalized': 0.08745696}
# Raw:  {'pm10': 35.33, 'no2': 23.18, 'so2': 16.35, 'soot': 22.06}
# Transformed: {'no2_normalized': -9.497978, 'pm10_normalized': 0.10687784, 'so2_normalized': 0.825407, 'soot_normalized': 0.1579931}
# Raw:  {'pm10': 37.0, 'no2': 32.27, 'so2': 21.65, 'soot': 33.83}
# Transformed: {'no2_normalized': -0.40797806, 'pm10_normalized': 0.11304315, 'so2_normalized': 6.1254063, 'soot_normalized': 0.27378258}
# Raw:  {'pm10': 33.33, 'no2': 19.33, 'so2': 16.28, 'soot': 25.68}
# Transformed: {'no2_normalized': -13.347979, 'pm10_normalized': 0.09949423, 'so2_normalized': 0.75540733, 'soot_normalized': 0.1936055}
# Raw:  {'pm10': 20.0, 'no2': 13.67, 'so2': 18.56, 'soot': 19.53}
# Transformed: {'no2_normalized': -19.007978, 'pm10_normalized': 0.050282422, 'so2_normalized': 3.035406, 'soot_normalized': 0.13310379}
# Raw:  {'pm10': 34.33, 'no2': 19.92, 'so2': 15.33, 'soot': 21.89}
# Transformed: {'no2_normalized': -12.757978, 'pm10_normalized': 0.10318603, 'so2_normalized': -0.19459343, 'soot_normalized': 0.15632069}
# Raw:  {'pm10': 52.67, 'no2': 23.0, 'so2': 17.33, 'soot': 29.32}
# Transformed: {'no2_normalized': -9.6779785, 'pm10_normalized': 0.17089377, 'so2_normalized': 1.8054066, 'soot_normalized': 0.22941464}
# Raw:  {'pm10': 75.33, 'no2': 23.17, 'so2': 13.78, 'soot': 35.26}
# Transformed: {'no2_normalized': -9.507978, 'pm10_normalized': 0.25455016, 'so2_normalized': -1.7445936, 'soot_normalized': 0.28785044}
# Raw:  {'pm10': 114.33, 'no2': 39.58, 'so2': 31.72, 'soot': 53.37}
# Transformed: {'no2_normalized': 6.9020233, 'pm10_normalized': 0.39853066, 'so2_normalized': 16.195406, 'soot_normalized': 0.46601078}
# Raw:  {'pm10': 123.0, 'no2': 39.08, 'so2': 35.06, 'soot': 52.26}
# Transformed: {'no2_normalized': 6.4020233, 'pm10_normalized': 0.43053865, 'so2_normalized': 19.535408, 'soot_normalized': 0.45509094}
# Raw:  {'pm10': 89.0, 'no2': 29.92, 'so2': 23.06, 'soot': 39.63}
# Transformed: {'no2_normalized': -2.7579784, 'pm10_normalized': 0.30501717, 'so2_normalized': 7.535406, 'soot_normalized': 0.33084112}
# Raw:  {'pm10': 72.33, 'no2': 31.0, 'so2': 23.72, 'soot': 37.89}
# Transformed: {'no2_normalized': -1.6779785, 'pm10_normalized': 0.24347475, 'so2_normalized': 8.195406, 'soot_normalized': 0.31372353}
# Raw:  {'pm10': 44.33, 'no2': 29.58, 'so2': 23.94, 'soot': 35.47}
# Transformed: {'no2_normalized': -3.0979786, 'pm10_normalized': 0.14010412, 'so2_normalized': 8.415407, 'soot_normalized': 0.28991637}
# Raw:  {'pm10': 36.67, 'no2': 31.5, 'so2': 20.72, 'soot': 35.47}
# Transformed: {'no2_normalized': -1.1779785, 'pm10_normalized': 0.11182485, 'so2_normalized': 5.195406, 'soot_normalized': 0.28991637}
# Raw:  {'pm10': 75.5, 'no2': 35.13, 'so2': 28.65, 'soot': 48.47}
# Transformed: {'no2_normalized': 2.4520226, 'pm10_normalized': 0.25517777, 'so2_normalized': 13.125406, 'soot_normalized': 0.41780618}
# Raw:  {'pm10': 56.75, 'no2': 30.25, 'so2': 26.5, 'soot': 41.53}
# Transformed: {'no2_normalized': -2.4279785, 'pm10_normalized': 0.18595636, 'so2_normalized': 10.975407, 'soot_normalized': 0.34953266}
# Raw:  {'pm10': 56.5, 'no2': 27.94, 'so2': 27.9, 'soot': 43.32}
# Transformed: {'no2_normalized': -4.737978, 'pm10_normalized': 0.18503341, 'so2_normalized': 12.375406, 'soot_normalized': 0.36714214}
# Raw:  {'pm10': 38.5, 'no2': 16.75, 'so2': 19.0, 'soot': 26.11}
# Transformed: {'no2_normalized': -15.9279785, 'pm10_normalized': 0.11858086, 'so2_normalized': 3.4754066, 'soot_normalized': 0.1978357}
# Raw:  {'pm10': 22.75, 'no2': 10.56, 'so2': 15.75, 'soot': 21.11}
# Transformed: {'no2_normalized': -22.117977, 'pm10_normalized': 0.06043489, 'so2_normalized': 0.22540665, 'soot_normalized': 0.14864732}
# Raw:  {'pm10': 33.0, 'no2': 17.81, 'so2': 15.8, 'soot': 23.79}
# Transformed: {'no2_normalized': -14.867979, 'pm10_normalized': 0.09827592, 'so2_normalized': 0.27540684, 'soot_normalized': 0.17501229}
# Raw:  {'pm10': 29.83, 'no2': 15.81, 'so2': 11.35, 'soot': 18.21}
# Transformed: {'no2_normalized': -16.867977, 'pm10_normalized': 0.0865729, 'so2_normalized': -4.174593, 'soot_normalized': 0.12011804}
# Raw:  {'pm10': 31.17, 'no2': 17.44, 'so2': 11.9, 'soot': 22.32}
# Transformed: {'no2_normalized': -15.237978, 'pm10_normalized': 0.09151992, 'so2_normalized': -3.6245937, 'soot_normalized': 0.16055089}
# Raw:  {'pm10': 33.17, 'no2': 22.81, 'so2': 17.1, 'soot': 26.16}
# Transformed: {'no2_normalized': -9.867979, 'pm10_normalized': 0.09890352, 'so2_normalized': 1.575407, 'soot_normalized': 0.19832759}
# Raw:  {'pm10': 42.0, 'no2': 20.75, 'so2': 14.5, 'soot': 25.11}
# Transformed: {'no2_normalized': -11.9279785, 'pm10_normalized': 0.1315022, 'so2_normalized': -1.0245934, 'soot_normalized': 0.18799803}
# Raw:  {'pm10': 32.67, 'no2': 22.13, 'so2': 17.85, 'soot': 24.83}
# Transformed: {'no2_normalized': -10.547979, 'pm10_normalized': 0.09705762, 'so2_normalized': 2.325407, 'soot_normalized': 0.18524347}
# Raw:  {'pm10': 25.2, 'no2': 17.44, 'so2': 14.25, 'soot': 22.0}
# Transformed: {'no2_normalized': -15.237978, 'pm10_normalized': 0.06947982, 'so2_normalized': -1.2745934, 'soot_normalized': 0.15740284}
# Raw:  {'pm10': 25.67, 'no2': 18.13, 'so2': 16.2, 'soot': 20.22}
# Transformed: {'no2_normalized': -14.547979, 'pm10_normalized': 0.071214974, 'so2_normalized': 0.6754074, 'soot_normalized': 0.13989177}
# Raw:  {'pm10': 42.0, 'no2': 18.06, 'so2': 14.0, 'soot': 21.83}
# Transformed: {'no2_normalized': -14.617979, 'pm10_normalized': 0.1315022, 'so2_normalized': -1.5245934, 'soot_normalized': 0.15573044}
# Raw:  {'pm10': 72.0, 'no2': 25.44, 'so2': 25.25, 'soot': 35.72}
# Transformed: {'no2_normalized': -7.237978, 'pm10_normalized': 0.24225645, 'so2_normalized': 9.725407, 'soot_normalized': 0.2923758}
# Raw:  {'pm10': 38.83, 'no2': 18.69, 'so2': 16.55, 'soot': 20.33}
# Transformed: {'no2_normalized': -13.987978, 'pm10_normalized': 0.11979917, 'so2_normalized': 1.0254059, 'soot_normalized': 0.14097393}
# Raw:  {'pm10': 41.33, 'no2': 17.19, 'so2': 13.65, 'soot': 18.78}
# Transformed: {'no2_normalized': -15.487978, 'pm10_normalized': 0.1290287, 'so2_normalized': -1.8745937, 'soot_normalized': 0.12572552}
# Raw:  {'pm10': 23.17, 'no2': 12.38, 'so2': 11.7, 'soot': 16.06}
# Transformed: {'no2_normalized': -20.297977, 'pm10_normalized': 0.061985455, 'so2_normalized': -3.8245935, 'soot_normalized': 0.09896703}
# Raw:  {'pm10': 27.0, 'no2': 16.63, 'so2': 12.3, 'soot': 18.28}
# Transformed: {'no2_normalized': -16.04798, 'pm10_normalized': 0.07612507, 'so2_normalized': -3.2245932, 'soot_normalized': 0.12080669}
# Raw:  {'pm10': 38.33, 'no2': 18.75, 'so2': 15.0, 'soot': 19.05}
# Transformed: {'no2_normalized': -13.9279785, 'pm10_normalized': 0.11795326, 'so2_normalized': -0.52459335, 'soot_normalized': 0.12838168}
# Raw:  {'pm10': 26.6, 'no2': 15.75, 'so2': 13.55, 'soot': 15.74}
# Transformed: {'no2_normalized': -16.927979, 'pm10_normalized': 0.07464836, 'so2_normalized': -1.9745932, 'soot_normalized': 0.09581898}
# Raw:  {'pm10': 31.0, 'no2': 14.94, 'so2': 12.4, 'soot': 16.42}
# Transformed: {'no2_normalized': -17.73798, 'pm10_normalized': 0.09089231, 'so2_normalized': -3.1245937, 'soot_normalized': 0.102508605}
# Raw:  {'pm10': 28.0, 'no2': 20.0, 'so2': 14.15, 'soot': 17.79}
# Transformed: {'no2_normalized': -12.6779785, 'pm10_normalized': 0.079816885, 'so2_normalized': -1.3745937, 'soot_normalized': 0.11598623}
# Raw:  {'pm10': 21.83, 'no2': 21.27, 'so2': 13.5, 'soot': 14.59}
# Transformed: {'no2_normalized': -11.407978, 'pm10_normalized': 0.05703843, 'so2_normalized': -2.0245934, 'soot_normalized': 0.084505655}
# Raw:  {'pm10': 28.83, 'no2': 18.57, 'so2': 12.6, 'soot': 17.0}
# Transformed: {'no2_normalized': -14.107979, 'pm10_normalized': 0.082881086, 'so2_normalized': -2.924593, 'soot_normalized': 0.10821445}
# Raw:  {'pm10': 34.67, 'no2': 26.33, 'so2': 17.4, 'soot': 21.24}
# Transformed: {'no2_normalized': -6.3479786, 'pm10_normalized': 0.10444123, 'so2_normalized': 1.8754063, 'soot_normalized': 0.1499262}
# Raw:  {'pm10': 34.17, 'no2': 28.0, 'so2': 17.95, 'soot': 20.88}
# Transformed: {'no2_normalized': -4.6779785, 'pm10_normalized': 0.10259533, 'so2_normalized': 2.4254074, 'soot_normalized': 0.14638464}
# Raw:  {'pm10': 27.33, 'no2': 22.6, 'so2': 14.85, 'soot': 16.71}
# Transformed: {'no2_normalized': -10.077978, 'pm10_normalized': 0.077343374, 'so2_normalized': -0.674593, 'soot_normalized': 0.10536152}
# Raw:  {'pm10': 47.83, 'no2': 13.29, 'so2': 10.95, 'soot': 15.88}
# Transformed: {'no2_normalized': -19.387978, 'pm10_normalized': 0.15302543, 'so2_normalized': -4.5745935, 'soot_normalized': 0.09719626}
# Raw:  {'pm10': 29.83, 'no2': 19.57, 'so2': 12.05, 'soot': 16.82}
# Transformed: {'no2_normalized': -13.107979, 'pm10_normalized': 0.0865729, 'so2_normalized': -3.4745932, 'soot_normalized': 0.10644367}
# Raw:  {'pm10': 34.2, 'no2': 19.21, 'so2': 9.9, 'soot': 19.44}
# Transformed: {'no2_normalized': -13.467979, 'pm10_normalized': 0.1027061, 'so2_normalized': -5.6245937, 'soot_normalized': 0.13221839}
# Raw:  {'pm10': 60.83, 'no2': 19.47, 'so2': 12.55, 'soot': 24.65}
# Transformed: {'no2_normalized': -13.207979, 'pm10_normalized': 0.20101894, 'so2_normalized': -2.9745932, 'soot_normalized': 0.18347268}
# Raw:  {'pm10': 39.17, 'no2': 17.46, 'so2': 10.95, 'soot': 20.5}
# Transformed: {'no2_normalized': -15.217979, 'pm10_normalized': 0.121054366, 'so2_normalized': -4.5745935, 'soot_normalized': 0.14264633}
# Raw:  {'pm10': 27.5, 'no2': 16.07, 'so2': 10.3, 'soot': 16.27}
# Transformed: {'no2_normalized': -16.607979, 'pm10_normalized': 0.07797098, 'so2_normalized': -5.224593, 'soot_normalized': 0.10103296}
# Raw:  {'pm10': 35.33, 'no2': 20.93, 'so2': 11.7, 'soot': 21.27}
# Transformed: {'no2_normalized': -11.747978, 'pm10_normalized': 0.10687784, 'so2_normalized': -3.8245935, 'soot_normalized': 0.15022135}
# Raw:  {'pm10': 51.83, 'no2': 31.07, 'so2': 12.45, 'soot': 29.2}
# Transformed: {'no2_normalized': -1.6079788, 'pm10_normalized': 0.16779266, 'so2_normalized': -3.0745935, 'soot_normalized': 0.22823413}
# Raw:  {'pm10': 53.6, 'no2': 29.0, 'so2': 14.1, 'soot': 27.6}
# Transformed: {'no2_normalized': -3.6779785, 'pm10_normalized': 0.17432715, 'so2_normalized': -1.424593, 'soot_normalized': 0.21249384}
# Raw:  {'pm10': 48.0, 'no2': 30.36, 'so2': 12.9, 'soot': 27.63}
# Transformed: {'no2_normalized': -2.317978, 'pm10_normalized': 0.15365304, 'so2_normalized': -2.6245937, 'soot_normalized': 0.21278895}
# Raw:  {'pm10': 39.0, 'no2': 30.8, 'so2': 11.25, 'soot': 32.88}
# Transformed: {'no2_normalized': -1.8779793, 'pm10_normalized': 0.12042677, 'so2_normalized': -4.2745934, 'soot_normalized': 0.26443678}
# Raw:  {'pm10': 65.8, 'no2': 34.33, 'so2': 14.15, 'soot': 42.71}
# Transformed: {'no2_normalized': 1.6520233, 'pm10_normalized': 0.21936724, 'so2_normalized': -1.3745937, 'soot_normalized': 0.36114115}
# Raw:  {'pm10': 61.4, 'no2': 38.6, 'so2': 19.2, 'soot': 42.67}
# Transformed: {'no2_normalized': 5.92202, 'pm10_normalized': 0.20312327, 'so2_normalized': 3.6754074, 'soot_normalized': 0.36074764}
# Raw:  {'pm10': 39.17, 'no2': 18.0, 'so2': 10.3, 'soot': 18.61}
# Transformed: {'no2_normalized': -14.6779785, 'pm10_normalized': 0.121054366, 'so2_normalized': -5.224593, 'soot_normalized': 0.12405312}
# Raw:  {'pm10': 35.33, 'no2': 15.27, 'so2': 9.8, 'soot': 12.89}
# Transformed: {'no2_normalized': -17.407978, 'pm10_normalized': 0.10687784, 'so2_normalized': -5.724593, 'soot_normalized': 0.067781605}
# Raw:  {'pm10': 44.0, 'no2': 15.36, 'so2': 8.8, 'soot': 13.94}
# Transformed: {'no2_normalized': -17.317978, 'pm10_normalized': 0.13888581, 'so2_normalized': -6.724593, 'soot_normalized': 0.07811116}
# Raw:  {'pm10': 32.83, 'no2': 22.57, 'so2': 11.6, 'soot': 24.76}
# Transformed: {'no2_normalized': -10.107979, 'pm10_normalized': 0.09764832, 'so2_normalized': -3.924593, 'soot_normalized': 0.18455483}
# Raw:  {'pm10': 40.83, 'no2': 25.5, 'so2': 12.3, 'soot': 29.24}
# Transformed: {'no2_normalized': -7.1779785, 'pm10_normalized': 0.12718278, 'so2_normalized': -3.2245932, 'soot_normalized': 0.22862762}
# Raw:  {'pm10': 45.67, 'no2': 39.69, 'so2': 14.7, 'soot': 42.74}
# Transformed: {'no2_normalized': 7.01202, 'pm10_normalized': 0.14505112, 'so2_normalized': -0.82459354, 'soot_normalized': 0.3614363}
# Raw:  {'pm10': 27.67, 'no2': 24.13, 'so2': 10.5, 'soot': 17.84}
# Transformed: {'no2_normalized': -8.547979, 'pm10_normalized': 0.078598596, 'so2_normalized': -5.0245934, 'soot_normalized': 0.11647811}
# Raw:  {'pm10': 24.67, 'no2': 22.94, 'so2': 9.45, 'soot': 17.11}
# Transformed: {'no2_normalized': -9.737978, 'pm10_normalized': 0.06752317, 'so2_normalized': -6.0745935, 'soot_normalized': 0.109296605}
# Raw:  {'pm10': 34.0, 'no2': 23.31, 'so2': 9.55, 'soot': 23.05}
# Transformed: {'no2_normalized': -9.367979, 'pm10_normalized': 0.10196773, 'so2_normalized': -5.974593, 'soot_normalized': 0.1677324}
# Raw:  {'pm10': 28.17, 'no2': 23.75, 'so2': 9.2, 'soot': 19.68}
# Transformed: {'no2_normalized': -8.9279785, 'pm10_normalized': 0.0804445, 'so2_normalized': -6.3245935, 'soot_normalized': 0.13457943}
# Raw:  {'pm10': 34.33, 'no2': 22.94, 'so2': 9.1, 'soot': 19.05}
# Transformed: {'no2_normalized': -9.737978, 'pm10_normalized': 0.10318603, 'so2_normalized': -6.424593, 'soot_normalized': 0.12838168}
# Raw:  {'pm10': 29.67, 'no2': 20.5, 'so2': 8.75, 'soot': 18.89}
# Transformed: {'no2_normalized': -12.1779785, 'pm10_normalized': 0.08598221, 'so2_normalized': -6.7745934, 'soot_normalized': 0.12680766}
# Raw:  {'pm10': 19.75, 'no2': 20.5, 'so2': 8.45, 'soot': 17.05}
# Transformed: {'no2_normalized': -12.1779785, 'pm10_normalized': 0.04935947, 'so2_normalized': -7.0745935, 'soot_normalized': 0.10870633}
# Raw:  {'pm10': 28.83, 'no2': 28.81, 'so2': 9.5, 'soot': 28.32}
# Transformed: {'no2_normalized': -3.867979, 'pm10_normalized': 0.082881086, 'so2_normalized': -6.0245934, 'soot_normalized': 0.21957697}
# Raw:  {'pm10': 39.0, 'no2': 28.13, 'so2': 11.3, 'soot': 27.16}
# Transformed: {'no2_normalized': -4.5479794, 'pm10_normalized': 0.12042677, 'so2_normalized': -4.224593, 'soot_normalized': 0.20816526}
# Raw:  {'pm10': 24.5, 'no2': 18.38, 'so2': 8.85, 'soot': 13.47}
# Transformed: {'no2_normalized': -14.297979, 'pm10_normalized': 0.06689555, 'so2_normalized': -6.674593, 'soot_normalized': 0.07348745}
# Raw:  {'pm10': 23.33, 'no2': 17.75, 'so2': 7.55, 'soot': 14.42}
# Transformed: {'no2_normalized': -14.9279785, 'pm10_normalized': 0.062576145, 'so2_normalized': -7.974593, 'soot_normalized': 0.082833245}
# Raw:  {'pm10': 24.2, 'no2': 19.38, 'so2': 9.55, 'soot': 16.95}
# Transformed: {'no2_normalized': -13.297979, 'pm10_normalized': 0.065788016, 'so2_normalized': -5.974593, 'soot_normalized': 0.10772258}
# Raw:  {'pm10': 24.2, 'no2': 23.93, 'so2': 9.05, 'soot': 22.95}
# Transformed: {'no2_normalized': -8.747978, 'pm10_normalized': 0.065788016, 'so2_normalized': -6.474593, 'soot_normalized': 0.16674864}
# Raw:  {'pm10': 17.6, 'no2': 21.2, 'so2': 8.85, 'soot': 19.26}
# Transformed: {'no2_normalized': -11.477978, 'pm10_normalized': 0.041422084, 'so2_normalized': -6.674593, 'soot_normalized': 0.13044761}
# Raw:  {'pm10': 28.0, 'no2': 15.5, 'so2': 7.9, 'soot': 18.63}
# Transformed: {'no2_normalized': -17.177979, 'pm10_normalized': 0.079816885, 'so2_normalized': -7.6245933, 'soot_normalized': 0.12424986}
# Raw:  {'pm10': 25.67, 'no2': 11.69, 'so2': 7.85, 'soot': 16.68}
# Transformed: {'no2_normalized': -20.98798, 'pm10_normalized': 0.071214974, 'so2_normalized': -7.6745934, 'soot_normalized': 0.105066404}
# Raw:  {'pm10': 37.0, 'no2': 19.94, 'so2': 9.3, 'soot': 21.74}
# Transformed: {'no2_normalized': -12.737978, 'pm10_normalized': 0.11304315, 'so2_normalized': -6.224593, 'soot_normalized': 0.15484504}
# Raw:  {'pm10': 33.67, 'no2': 22.75, 'so2': 10.1, 'soot': 24.89}
# Transformed: {'no2_normalized': -9.9279785, 'pm10_normalized': 0.100749426, 'so2_normalized': -5.424593, 'soot_normalized': 0.18583372}
# Raw:  {'pm10': 25.17, 'no2': 18.44, 'so2': 8.6, 'soot': 20.05}
# Transformed: {'no2_normalized': -14.237978, 'pm10_normalized': 0.06936907, 'so2_normalized': -6.924593, 'soot_normalized': 0.13821937}
# Raw:  {'pm10': 22.0, 'no2': 21.0, 'so2': 8.8, 'soot': 21.05}
# Transformed: {'no2_normalized': -11.6779785, 'pm10_normalized': 0.057666037, 'so2_normalized': -6.724593, 'soot_normalized': 0.14805704}
# Raw:  {'pm10': 23.0, 'no2': 21.75, 'so2': 8.5, 'soot': 21.74}
# Transformed: {'no2_normalized': -10.9279785, 'pm10_normalized': 0.06135784, 'so2_normalized': -7.0245934, 'soot_normalized': 0.15484504}
# Raw:  {'pm10': 26.67, 'no2': 29.63, 'so2': 10.85, 'soot': 30.63}
# Transformed: {'no2_normalized': -3.0479794, 'pm10_normalized': 0.07490678, 'so2_normalized': -4.674593, 'soot_normalized': 0.242302}
# Raw:  {'pm10': 35.75, 'no2': 33.25, 'so2': 13.4, 'soot': 37.0}
# Transformed: {'no2_normalized': 0.5720215, 'pm10_normalized': 0.1084284, 'so2_normalized': -2.1245937, 'soot_normalized': 0.304968}
# Raw:  {'pm10': 31.0, 'no2': 30.13, 'so2': 11.55, 'soot': 30.42}
# Transformed: {'no2_normalized': -2.5479794, 'pm10_normalized': 0.09089231, 'so2_normalized': -3.9745932, 'soot_normalized': 0.24023609}
# Raw:  {'pm10': 36.5, 'no2': 30.31, 'so2': 17.4, 'soot': 27.63}
# Transformed: {'no2_normalized': -2.367979, 'pm10_normalized': 0.11119725, 'so2_normalized': 1.8754063, 'soot_normalized': 0.21278895}
# Raw:  {'pm10': 31.5, 'no2': 26.13, 'so2': 10.65, 'soot': 22.37}
# Transformed: {'no2_normalized': -6.5479794, 'pm10_normalized': 0.09273821, 'so2_normalized': -4.8745937, 'soot_normalized': 0.1610428}
# Raw:  {'pm10': 20.17, 'no2': 17.25, 'so2': 9.1, 'soot': 18.21}
# Transformed: {'no2_normalized': -15.4279785, 'pm10_normalized': 0.05091003, 'so2_normalized': -6.424593, 'soot_normalized': 0.12011804}
# Raw:  {'pm10': 32.5, 'no2': 22.44, 'so2': 9.35, 'soot': 22.95}
# Transformed: {'no2_normalized': -10.237978, 'pm10_normalized': 0.09643002, 'so2_normalized': -6.174593, 'soot_normalized': 0.16674864}
# Raw:  {'pm10': 47.67, 'no2': 29.81, 'so2': 12.95, 'soot': 28.84}
# Transformed: {'no2_normalized': -2.867979, 'pm10_normalized': 0.15243474, 'so2_normalized': -2.5745935, 'soot_normalized': 0.22469255}
# Raw:  {'pm10': 40.17, 'no2': 28.81, 'so2': 13.3, 'soot': 25.42}
# Transformed: {'no2_normalized': -3.867979, 'pm10_normalized': 0.12474617, 'so2_normalized': -2.2245932, 'soot_normalized': 0.1910477}
# Raw:  {'pm10': 44.17, 'no2': 27.06, 'so2': 11.9, 'soot': 25.37}
# Transformed: {'no2_normalized': -5.617979, 'pm10_normalized': 0.1395134, 'so2_normalized': -3.6245937, 'soot_normalized': 0.19055583}
# Raw:  {'pm10': 38.17, 'no2': 25.19, 'so2': 11.8, 'soot': 23.32}
# Transformed: {'no2_normalized': -7.487978, 'pm10_normalized': 0.11736256, 'so2_normalized': -3.7245932, 'soot_normalized': 0.17038858}
# Raw:  {'pm10': 34.17, 'no2': 19.07, 'so2': 10.25, 'soot': 21.11}
# Transformed: {'no2_normalized': -13.607979, 'pm10_normalized': 0.10259533, 'so2_normalized': -5.2745934, 'soot_normalized': 0.14864732}
# Raw:  {'pm10': 31.17, 'no2': 16.4, 'so2': 9.45, 'soot': 16.94}
# Transformed: {'no2_normalized': -16.277979, 'pm10_normalized': 0.09151992, 'so2_normalized': -6.0745935, 'soot_normalized': 0.1076242}
# Raw:  {'pm10': 35.67, 'no2': 25.67, 'so2': 10.0, 'soot': 20.78}
# Transformed: {'no2_normalized': -7.0079784, 'pm10_normalized': 0.10813304, 'so2_normalized': -5.5245934, 'soot_normalized': 0.14540088}
# Raw:  {'pm10': 43.17, 'no2': 34.6, 'so2': 13.5, 'soot': 27.78}
# Transformed: {'no2_normalized': 1.92202, 'pm10_normalized': 0.1358216, 'so2_normalized': -2.0245934, 'soot_normalized': 0.21426463}
# Raw:  {'pm10': 23.67, 'no2': 23.27, 'so2': 9.75, 'soot': 16.89}
# Transformed: {'no2_normalized': -9.407978, 'pm10_normalized': 0.06383136, 'so2_normalized': -5.7745934, 'soot_normalized': 0.1071323}
# Raw:  {'pm10': 29.5, 'no2': 25.0, 'so2': 10.45, 'soot': 23.72}
# Transformed: {'no2_normalized': -7.6779785, 'pm10_normalized': 0.0853546, 'so2_normalized': -5.0745935, 'soot_normalized': 0.17432365}
# Raw:  {'pm10': 39.17, 'no2': 30.6, 'so2': 10.4, 'soot': 25.89}
# Transformed: {'no2_normalized': -2.0779781, 'pm10_normalized': 0.121054366, 'so2_normalized': -5.1245937, 'soot_normalized': 0.19567141}
# Raw:  {'pm10': 35.0, 'no2': 29.07, 'so2': 11.55, 'soot': 22.16}
# Transformed: {'no2_normalized': -3.6079788, 'pm10_normalized': 0.10565954, 'so2_normalized': -3.9745932, 'soot_normalized': 0.15897687}
# Raw:  {'pm10': 28.0, 'no2': 20.33, 'so2': 9.55, 'soot': 17.42}
# Transformed: {'no2_normalized': -12.347979, 'pm10_normalized': 0.079816885, 'so2_normalized': -5.974593, 'soot_normalized': 0.11234628}
# Raw:  {'pm10': 20.5, 'no2': 18.0, 'so2': 8.9, 'soot': 16.33}
# Transformed: {'no2_normalized': -14.6779785, 'pm10_normalized': 0.052128326, 'so2_normalized': -6.6245937, 'soot_normalized': 0.10162321}
# Raw:  {'pm10': 21.17, 'no2': 19.47, 'so2': 9.45, 'soot': 17.11}
# Transformed: {'no2_normalized': -13.207979, 'pm10_normalized': 0.054601837, 'so2_normalized': -6.0745935, 'soot_normalized': 0.109296605}
# Raw:  {'pm10': 23.33, 'no2': 17.67, 'so2': 9.7, 'soot': 17.61}
# Transformed: {'no2_normalized': -15.007978, 'pm10_normalized': 0.062576145, 'so2_normalized': -5.8245935, 'soot_normalized': 0.11421544}
# Raw:  {'pm10': 28.33, 'no2': 19.73, 'so2': 10.5, 'soot': 17.67}
# Transformed: {'no2_normalized': -12.947979, 'pm10_normalized': 0.08103518, 'so2_normalized': -5.0245934, 'soot_normalized': 0.1148057}
# Raw:  {'pm10': 28.5, 'no2': 22.33, 'so2': 9.1, 'soot': 16.42}
# Transformed: {'no2_normalized': -10.347979, 'pm10_normalized': 0.08166279, 'so2_normalized': -6.424593, 'soot_normalized': 0.102508605}
# Raw:  {'pm10': 21.67, 'no2': 23.25, 'so2': 9.15, 'soot': 15.79}
# Transformed: {'no2_normalized': -9.4279785, 'pm10_normalized': 0.05644774, 'so2_normalized': -6.3745937, 'soot_normalized': 0.09631086}
# Raw:  {'pm10': 26.17, 'no2': 23.87, 'so2': 9.7, 'soot': 17.21}
# Transformed: {'no2_normalized': -8.807978, 'pm10_normalized': 0.07306088, 'so2_normalized': -5.8245935, 'soot_normalized': 0.11028036}
# Raw:  {'pm10': 25.67, 'no2': 24.56, 'so2': 10.0, 'soot': 20.21}
# Transformed: {'no2_normalized': -8.117979, 'pm10_normalized': 0.071214974, 'so2_normalized': -5.5245934, 'soot_normalized': 0.1397934}
# Raw:  {'pm10': 23.67, 'no2': 26.5, 'so2': 9.35, 'soot': 17.26}
# Transformed: {'no2_normalized': -6.1779785, 'pm10_normalized': 0.06383136, 'so2_normalized': -6.174593, 'soot_normalized': 0.11077225}
# Raw:  {'pm10': 24.17, 'no2': 25.0, 'so2': 9.3, 'soot': 20.42}
# Transformed: {'no2_normalized': -7.6779785, 'pm10_normalized': 0.06567726, 'so2_normalized': -6.224593, 'soot_normalized': 0.14185931}
# Raw:  {'pm10': 27.5, 'no2': 24.5, 'so2': 9.75, 'soot': 14.89}
# Transformed: {'no2_normalized': -8.1779785, 'pm10_normalized': 0.07797098, 'so2_normalized': -5.7745934, 'soot_normalized': 0.08745696}
# Raw:  {'pm10': 25.83, 'no2': 25.27, 'so2': 9.85, 'soot': 23.95}
# Transformed: {'no2_normalized': -7.407978, 'pm10_normalized': 0.07180566, 'so2_normalized': -5.674593, 'soot_normalized': 0.17658632}
# Raw:  {'pm10': 38.5, 'no2': 29.94, 'so2': 11.9, 'soot': 25.16}
# Transformed: {'no2_normalized': -2.737978, 'pm10_normalized': 0.11858086, 'so2_normalized': -3.6245937, 'soot_normalized': 0.1884899}
# Raw:  {'pm10': 31.83, 'no2': 26.38, 'so2': 10.85, 'soot': 20.79}
# Transformed: {'no2_normalized': -6.2979794, 'pm10_normalized': 0.093956515, 'so2_normalized': -4.674593, 'soot_normalized': 0.14549926}
# Raw:  {'pm10': 30.8, 'no2': 20.69, 'so2': 9.6, 'soot': 16.11}
# Transformed: {'no2_normalized': -11.987978, 'pm10_normalized': 0.09015394, 'so2_normalized': -5.924593, 'soot_normalized': 0.099458925}
# Raw:  {'pm10': 18.5, 'no2': 21.69, 'so2': 9.95, 'soot': 17.79}
# Transformed: {'no2_normalized': -10.987978, 'pm10_normalized': 0.04474471, 'so2_normalized': -5.5745935, 'soot_normalized': 0.11598623}
# Raw:  {'pm10': 24.5, 'no2': 24.75, 'so2': 10.45, 'soot': 20.32}
# Transformed: {'no2_normalized': -7.9279785, 'pm10_normalized': 0.06689555, 'so2_normalized': -5.0745935, 'soot_normalized': 0.14087555}
# Raw:  {'pm10': 23.67, 'no2': 27.88, 'so2': 11.75, 'soot': 22.53}
# Transformed: {'no2_normalized': -4.7979794, 'pm10_normalized': 0.06383136, 'so2_normalized': -3.7745934, 'soot_normalized': 0.16261682}
# Raw:  {'pm10': 25.67, 'no2': 29.0, 'so2': 12.4, 'soot': 20.89}
# Transformed: {'no2_normalized': -3.6779785, 'pm10_normalized': 0.071214974, 'so2_normalized': -3.1245937, 'soot_normalized': 0.14648302}
# Raw:  {'pm10': 25.5, 'no2': 26.94, 'so2': 12.65, 'soot': 21.11}
# Transformed: {'no2_normalized': -5.737978, 'pm10_normalized': 0.07058736, 'so2_normalized': -2.8745937, 'soot_normalized': 0.14864732}
# Raw:  {'pm10': 16.67, 'no2': 23.5, 'so2': 10.75, 'soot': 19.11}
# Transformed: {'no2_normalized': -9.1779785, 'pm10_normalized': 0.037988704, 'so2_normalized': -4.7745934, 'soot_normalized': 0.12897196}
# Raw:  {'pm10': 31.5, 'no2': 28.31, 'so2': 12.7, 'soot': 19.44}
# Transformed: {'no2_normalized': -4.367979, 'pm10_normalized': 0.09273821, 'so2_normalized': -2.8245935, 'soot_normalized': 0.13221839}
# Raw:  {'pm10': 31.67, 'no2': 25.73, 'so2': 10.85, 'soot': 19.65}
# Transformed: {'no2_normalized': -6.947979, 'pm10_normalized': 0.093365826, 'so2_normalized': -4.674593, 'soot_normalized': 0.1342843}
# Raw:  {'pm10': 26.67, 'no2': 20.07, 'so2': 9.2, 'soot': 18.0}
# Transformed: {'no2_normalized': -12.607979, 'pm10_normalized': 0.07490678, 'so2_normalized': -6.3245935, 'soot_normalized': 0.11805213}
# Raw:  {'pm10': 10.0, 'no2': 19.87, 'so2': 9.65, 'soot': 16.41}
# Transformed: {'no2_normalized': -12.807978, 'pm10_normalized': 0.013364344, 'so2_normalized': -5.8745937, 'soot_normalized': 0.10241023}
# Raw:  {'pm10': 11.83, 'no2': 20.73, 'so2': 9.8, 'soot': 18.56}
# Transformed: {'no2_normalized': -11.947979, 'pm10_normalized': 0.020120353, 'so2_normalized': -5.724593, 'soot_normalized': 0.123561226}
# Raw:  {'pm10': 23.67, 'no2': 25.0, 'so2': 11.9, 'soot': 17.67}
# Transformed: {'no2_normalized': -7.6779785, 'pm10_normalized': 0.06383136, 'so2_normalized': -3.6245937, 'soot_normalized': 0.1148057}
# Raw:  {'pm10': 20.33, 'no2': 24.33, 'so2': 10.85, 'soot': 16.72}
# Transformed: {'no2_normalized': -8.347979, 'pm10_normalized': 0.05150072, 'so2_normalized': -4.674593, 'soot_normalized': 0.1054599}
# Raw:  {'pm10': 18.67, 'no2': 21.73, 'so2': 11.0, 'soot': 13.61}
# Transformed: {'no2_normalized': -10.947979, 'pm10_normalized': 0.04537232, 'so2_normalized': -4.5245934, 'soot_normalized': 0.07486472}
# Raw:  {'pm10': 20.33, 'no2': 22.87, 'so2': 11.5, 'soot': 18.78}
# Transformed: {'no2_normalized': -9.807978, 'pm10_normalized': 0.05150072, 'so2_normalized': -4.0245934, 'soot_normalized': 0.12572552}
# Raw:  {'pm10': 32.5, 'no2': 22.0, 'so2': 10.45, 'soot': 20.0}
# Transformed: {'no2_normalized': -10.6779785, 'pm10_normalized': 0.09643002, 'so2_normalized': -5.0745935, 'soot_normalized': 0.13772748}
# Raw:  {'pm10': 33.25, 'no2': 24.93, 'so2': 10.8, 'soot': 22.56}
# Transformed: {'no2_normalized': -7.747978, 'pm10_normalized': 0.09919887, 'so2_normalized': -4.724593, 'soot_normalized': 0.16291194}
# Raw:  {'pm10': 26.5, 'no2': 22.6, 'so2': 10.5, 'soot': 19.11}
# Transformed: {'no2_normalized': -10.077978, 'pm10_normalized': 0.07427917, 'so2_normalized': -5.0245934, 'soot_normalized': 0.12897196}
# Raw:  {'pm10': 29.25, 'no2': 26.6, 'so2': 10.3, 'soot': 23.28}
# Transformed: {'no2_normalized': -6.077978, 'pm10_normalized': 0.08443164, 'so2_normalized': -5.224593, 'soot_normalized': 0.16999508}
# Raw:  {'pm10': 33.9, 'no2': 25.69, 'so2': 10.28, 'soot': 26.33}
# Transformed: {'no2_normalized': -6.987978, 'pm10_normalized': 0.10159855, 'so2_normalized': -5.2445936, 'soot_normalized': 0.19999999}
# Raw:  {'pm10': 40.03, 'no2': 28.76, 'so2': 10.28, 'soot': 29.17}
# Transformed: {'no2_normalized': -3.9179783, 'pm10_normalized': 0.12422933, 'so2_normalized': -5.2445936, 'soot_normalized': 0.227939}
# Raw:  {'pm10': 38.77, 'no2': 28.01, 'so2': 10.72, 'soot': 23.17}
# Transformed: {'no2_normalized': -4.6679783, 'pm10_normalized': 0.11957765, 'so2_normalized': -4.804593, 'soot_normalized': 0.16891293}
# Raw:  {'pm10': 33.68, 'no2': 21.45, 'so2': 9.28, 'soot': 19.89}
# Transformed: {'no2_normalized': -11.227978, 'pm10_normalized': 0.10078635, 'so2_normalized': -6.2445936, 'soot_normalized': 0.13664533}
# Raw:  {'pm10': 26.18, 'no2': 18.79, 'so2': 9.35, 'soot': 16.83}
# Transformed: {'no2_normalized': -13.887978, 'pm10_normalized': 0.073097795, 'so2_normalized': -6.174593, 'soot_normalized': 0.10654205}
# Raw:  {'pm10': 31.15, 'no2': 28.15, 'so2': 9.67, 'soot': 25.11}
# Transformed: {'no2_normalized': -4.527979, 'pm10_normalized': 0.09144608, 'so2_normalized': -5.8545933, 'soot_normalized': 0.18799803}
# Raw:  {'pm10': 32.42, 'no2': 26.43, 'so2': 11.57, 'soot': 23.28}
# Transformed: {'no2_normalized': -6.247978, 'pm10_normalized': 0.09613466, 'so2_normalized': -3.9545937, 'soot_normalized': 0.16999508}
# Raw:  {'pm10': 24.1, 'no2': 23.91, 'so2': 9.83, 'soot': 17.06}
# Transformed: {'no2_normalized': -8.767979, 'pm10_normalized': 0.06541884, 'so2_normalized': -5.6945934, 'soot_normalized': 0.10880471}
# Raw:  {'pm10': 21.87, 'no2': 24.86, 'so2': 9.44, 'soot': 25.06}
# Transformed: {'no2_normalized': -7.817978, 'pm10_normalized': 0.057186108, 'so2_normalized': -6.084594, 'soot_normalized': 0.18750612}
# Raw:  {'pm10': 25.8, 'no2': 24.5, 'so2': 10.49, 'soot': 19.95}
# Transformed: {'no2_normalized': -8.1779785, 'pm10_normalized': 0.0716949, 'so2_normalized': -5.0345936, 'soot_normalized': 0.13723561}
# Raw:  {'pm10': 15.02, 'no2': 18.2, 'so2': 9.03, 'soot': 13.16}
# Transformed: {'no2_normalized': -14.477978, 'pm10_normalized': 0.03189722, 'so2_normalized': -6.4945936, 'soot_normalized': 0.070437774}
# Raw:  {'pm10': 16.43, 'no2': 17.79, 'so2': 9.07, 'soot': 16.21}
# Transformed: {'no2_normalized': -14.887978, 'pm10_normalized': 0.03710267, 'so2_normalized': -6.4545937, 'soot_normalized': 0.10044268}
# Raw:  {'pm10': 23.88, 'no2': 25.64, 'so2': 10.05, 'soot': 21.84}
# Transformed: {'no2_normalized': -7.037979, 'pm10_normalized': 0.06460664, 'so2_normalized': -5.474593, 'soot_normalized': 0.15582882}
# Raw:  {'pm10': 32.32, 'no2': 28.14, 'so2': 10.79, 'soot': 23.05}
# Transformed: {'no2_normalized': -4.537979, 'pm10_normalized': 0.095765494, 'so2_normalized': -4.7345934, 'soot_normalized': 0.1677324}
# Raw:  {'pm10': 43.03, 'no2': 27.55, 'so2': 12.89, 'soot': 28.28}
# Transformed: {'no2_normalized': -5.1279793, 'pm10_normalized': 0.13530475, 'so2_normalized': -2.634593, 'soot_normalized': 0.21918346}
# Raw:  {'pm10': 45.87, 'no2': 31.64, 'so2': 12.04, 'soot': 23.56}
# Transformed: {'no2_normalized': -1.0379791, 'pm10_normalized': 0.14578949, 'so2_normalized': -3.4845934, 'soot_normalized': 0.17274961}
# Raw:  {'pm10': 40.35, 'no2': 27.91, 'so2': 11.48, 'soot': 19.67}
# Transformed: {'no2_normalized': -4.7679787, 'pm10_normalized': 0.1254107, 'so2_normalized': -4.044594, 'soot_normalized': 0.13448106}
# Raw:  {'pm10': 43.2, 'no2': 21.54, 'so2': 10.99, 'soot': 12.17}
# Transformed: {'no2_normalized': -11.137978, 'pm10_normalized': 0.13593237, 'so2_normalized': -4.5345936, 'soot_normalized': 0.060698472}
# Raw:  {'pm10': 30.17, 'no2': 19.47, 'so2': 9.78, 'soot': 12.44}
# Transformed: {'no2_normalized': -13.207979, 'pm10_normalized': 0.087828115, 'so2_normalized': -5.7445936, 'soot_normalized': 0.06335464}
# Raw:  {'pm10': 24.0, 'no2': 24.83, 'so2': 10.55, 'soot': 22.67}
# Transformed: {'no2_normalized': -7.8479786, 'pm10_normalized': 0.06504965, 'so2_normalized': -4.974593, 'soot_normalized': 0.16399409}
# Raw:  {'pm10': 28.35, 'no2': 27.93, 'so2': 8.18, 'soot': 22.72}
# Transformed: {'no2_normalized': -4.747978, 'pm10_normalized': 0.081109025, 'so2_normalized': -7.344593, 'soot_normalized': 0.16448596}
# Raw:  {'pm10': 25.25, 'no2': 29.63, 'so2': 7.72, 'soot': 22.33}
# Transformed: {'no2_normalized': -3.0479794, 'pm10_normalized': 0.06966441, 'so2_normalized': -7.8045936, 'soot_normalized': 0.16064927}
# Raw:  {'pm10': 33.55, 'no2': 36.37, 'so2': 8.21, 'soot': 29.5}
# Transformed: {'no2_normalized': 3.6920204, 'pm10_normalized': 0.100306414, 'so2_normalized': -7.3145933, 'soot_normalized': 0.23118542}
# ...
# Raw:  {'pm10': 34.17, 'no2': 27.51, 'so2': 12.44, 'soot': 15.29}
# Transformed: {'no2_normalized': -5.1679783, 'pm10_normalized': 0.10259533, 'so2_normalized': -3.0845938, 'soot_normalized': 0.091392025}
# Raw:  {'pm10': 32.9, 'no2': 30.44, 'so2': 12.0, 'soot': 13.99}
# Transformed: {'no2_normalized': -2.237978, 'pm10_normalized': 0.097906746, 'so2_normalized': -3.5245934, 'soot_normalized': 0.078603044}
# Raw:  {'pm10': 53.7, 'no2': 40.64, 'so2': 16.37, 'soot': 21.64}
# Transformed: {'no2_normalized': 7.962021, 'pm10_normalized': 0.17469634, 'so2_normalized': 0.8454075, 'soot_normalized': 0.15386127}
# Raw:  {'pm10': 74.78, 'no2': 50.49, 'so2': 13.68, 'soot': 28.34}
# Transformed: {'no2_normalized': 17.812023, 'pm10_normalized': 0.25251967, 'so2_normalized': -1.844593, 'soot_normalized': 0.21977372}
# Raw:  {'pm10': 57.13, 'no2': 52.83, 'so2': 14.17, 'soot': 23.18}
# Transformed: {'no2_normalized': 20.152023, 'pm10_normalized': 0.18735924, 'so2_normalized': -1.3545933, 'soot_normalized': 0.16901131}
# Raw:  {'pm10': 53.88, 'no2': 49.65, 'so2': 12.7, 'soot': 21.81}
# Transformed: {'no2_normalized': 16.972023, 'pm10_normalized': 0.17536087, 'so2_normalized': -2.8245935, 'soot_normalized': 0.15553369}
# Raw:  {'pm10': 33.63, 'no2': 37.85, 'so2': 12.58, 'soot': 18.28}
# Transformed: {'no2_normalized': 5.17202, 'pm10_normalized': 0.10060176, 'so2_normalized': -2.9445934, 'soot_normalized': 0.12080669}
# Raw:  {'pm10': 40.23, 'no2': 43.25, 'so2': 12.56, 'soot': 20.93}
# Transformed: {'no2_normalized': 10.5720215, 'pm10_normalized': 0.12496769, 'so2_normalized': -2.964593, 'soot_normalized': 0.14687653}
# Raw:  {'pm10': 27.85, 'no2': 39.97, 'so2': 12.31, 'soot': 16.56}
# Transformed: {'no2_normalized': 7.2920227, 'pm10_normalized': 0.07926312, 'so2_normalized': -3.214593, 'soot_normalized': 0.103885874}
# Raw:  {'pm10': 41.93, 'no2': 38.29, 'so2': 14.06, 'soot': 17.41}
# Transformed: {'no2_normalized': 5.6120224, 'pm10_normalized': 0.13124377, 'so2_normalized': -1.4645929, 'soot_normalized': 0.1122479}
# Raw:  {'pm10': 47.85, 'no2': 48.91, 'so2': 15.48, 'soot': 22.3}
# Transformed: {'no2_normalized': 16.232021, 'pm10_normalized': 0.15309927, 'so2_normalized': -0.04459381, 'soot_normalized': 0.16035414}
# Raw:  {'pm10': 54.2, 'no2': 53.99, 'so2': 15.39, 'soot': 19.85}
# Transformed: {'no2_normalized': 21.312023, 'pm10_normalized': 0.17654225, 'so2_normalized': -0.13459301, 'soot_normalized': 0.13625184}
# Raw:  {'pm10': 25.95, 'no2': 36.62, 'so2': 10.09, 'soot': 13.38}
# Transformed: {'no2_normalized': 3.9420204, 'pm10_normalized': 0.072248675, 'so2_normalized': -5.434593, 'soot_normalized': 0.07260206}
# Raw:  {'pm10': 21.2, 'no2': 33.32, 'so2': 10.04, 'soot': 14.46}
# Transformed: {'no2_normalized': 0.6420212, 'pm10_normalized': 0.054712594, 'so2_normalized': -5.4845934, 'soot_normalized': 0.083226755}
# Raw:  {'pm10': 25.2, 'no2': 35.54, 'so2': 15.39, 'soot': 14.41}
# Transformed: {'no2_normalized': 2.8620224, 'pm10_normalized': 0.06947982, 'so2_normalized': -0.13459301, 'soot_normalized': 0.08273487}
# Raw:  {'pm10': 21.73, 'no2': 30.34, 'so2': 14.31, 'soot': 15.31}
# Transformed: {'no2_normalized': -2.3379784, 'pm10_normalized': 0.05666925, 'so2_normalized': -1.2145929, 'soot_normalized': 0.09158878}
# Raw:  {'pm10': 19.0, 'no2': 29.7, 'so2': 11.03, 'soot': 13.63}
# Transformed: {'no2_normalized': -2.9779778, 'pm10_normalized': 0.046590615, 'so2_normalized': -4.4945936, 'soot_normalized': 0.075061485}
# Raw:  {'pm10': 38.15, 'no2': 37.31, 'so2': 15.98, 'soot': 17.72}
# Transformed: {'no2_normalized': 4.632023, 'pm10_normalized': 0.11728874, 'so2_normalized': 0.4554062, 'soot_normalized': 0.11529758}
# Raw:  {'pm10': 44.1, 'no2': 39.72, 'so2': 18.52, 'soot': 16.19}
# Transformed: {'no2_normalized': 7.0420227, 'pm10_normalized': 0.13925499, 'so2_normalized': 2.995407, 'soot_normalized': 0.10024594}
# Raw:  {'pm10': 48.13, 'no2': 34.53, 'so2': 15.38, 'soot': 17.83}
# Transformed: {'no2_normalized': 1.8520203, 'pm10_normalized': 0.15413298, 'so2_normalized': -0.14459324, 'soot_normalized': 0.11637972}
# Raw:  {'pm10': 80.6, 'no2': 35.09, 'so2': 15.05, 'soot': 21.1}
# Transformed: {'no2_normalized': 2.4120216, 'pm10_normalized': 0.27400598, 'so2_normalized': -0.47459316, 'soot_normalized': 0.14854893}
# Raw:  {'pm10': 76.83, 'no2': 48.86, 'so2': 18.59, 'soot': 22.71}
# Transformed: {'no2_normalized': 16.182022, 'pm10_normalized': 0.26008788, 'so2_normalized': 3.0654068, 'soot_normalized': 0.16438758}
# Raw:  {'pm10': 63.58, 'no2': 50.83, 'so2': 18.2, 'soot': 20.75}
# Transformed: {'no2_normalized': 18.152023, 'pm10_normalized': 0.21117142, 'so2_normalized': 2.6754074, 'soot_normalized': 0.14510575}
# Raw:  {'pm10': 76.58, 'no2': 49.24, 'so2': 17.4, 'soot': 24.63}
# Transformed: {'no2_normalized': 16.562023, 'pm10_normalized': 0.25916493, 'so2_normalized': 1.8754063, 'soot_normalized': 0.18327592}
# Raw:  {'pm10': 48.1, 'no2': 33.23, 'so2': 16.24, 'soot': 20.34}
# Transformed: {'no2_normalized': 0.552021, 'pm10_normalized': 0.15402222, 'so2_normalized': 0.7154064, 'soot_normalized': 0.1410723}
# Raw:  {'pm10': 41.7, 'no2': 42.15, 'so2': 12.81, 'soot': 19.26}
# Transformed: {'no2_normalized': 9.472023, 'pm10_normalized': 0.13039465, 'so2_normalized': -2.714593, 'soot_normalized': 0.13044761}
# Raw:  {'pm10': 39.53, 'no2': 33.64, 'so2': 10.92, 'soot': 16.76}
# Transformed: {'no2_normalized': 0.9620209, 'pm10_normalized': 0.12238342, 'so2_normalized': -4.6045933, 'soot_normalized': 0.105853416}
# Raw:  {'pm10': 43.15, 'no2': 31.27, 'so2': 7.78, 'soot': 16.78}
# Transformed: {'no2_normalized': -1.407978, 'pm10_normalized': 0.13574778, 'so2_normalized': -7.744593, 'soot_normalized': 0.10605017}
# Raw:  {'pm10': 37.75, 'no2': 35.07, 'so2': 9.93, 'soot': 16.31}
# Transformed: {'no2_normalized': 2.3920212, 'pm10_normalized': 0.11581201, 'so2_normalized': -5.594593, 'soot_normalized': 0.10142645}
# Raw:  {'pm10': 48.85, 'no2': 35.01, 'so2': 10.1, 'soot': 13.81}
# Transformed: {'no2_normalized': 2.3320198, 'pm10_normalized': 0.15679108, 'so2_normalized': -5.424593, 'soot_normalized': 0.076832265}
# Raw:  {'pm10': 49.2, 'no2': 42.74, 'so2': 11.7, 'soot': 15.83}
# Transformed: {'no2_normalized': 10.062023, 'pm10_normalized': 0.15808322, 'so2_normalized': -3.8245935, 'soot_normalized': 0.09670437}
# Raw:  {'pm10': 49.65, 'no2': 44.01, 'so2': 12.48, 'soot': 18.78}
# Transformed: {'no2_normalized': 11.33202, 'pm10_normalized': 0.15974453, 'so2_normalized': -3.0445938, 'soot_normalized': 0.12572552}
# Raw:  {'pm10': 35.98, 'no2': 33.62, 'so2': 10.33, 'soot': 17.32}
# Transformed: {'no2_normalized': 0.9420204, 'pm10_normalized': 0.10927751, 'so2_normalized': -5.1945934, 'soot_normalized': 0.11136251}
# Raw:  {'pm10': 31.35, 'no2': 27.43, 'so2': 12.98, 'soot': 16.06}
# Transformed: {'no2_normalized': -5.247978, 'pm10_normalized': 0.09218445, 'so2_normalized': -2.5445938, 'soot_normalized': 0.09896703}
# Raw:  {'pm10': 37.8, 'no2': 28.23, 'so2': 10.92, 'soot': 13.54}
# Transformed: {'no2_normalized': -4.447979, 'pm10_normalized': 0.1159966, 'so2_normalized': -4.6045933, 'soot_normalized': 0.07417609}
# Raw:  {'pm10': 32.88, 'no2': 34.86, 'so2': 11.08, 'soot': 10.47}
# Transformed: {'no2_normalized': 2.182022, 'pm10_normalized': 0.09783291, 'so2_normalized': -4.4445934, 'soot_normalized': 0.043974422}
# Raw:  {'pm10': 30.68, 'no2': 27.07, 'so2': 9.95, 'soot': 11.03}
# Transformed: {'no2_normalized': -5.607979, 'pm10_normalized': 0.08971093, 'so2_normalized': -5.5745935, 'soot_normalized': 0.049483515}
# Raw:  {'pm10': 27.85, 'no2': 23.1, 'so2': 12.35, 'soot': 11.38}
# Transformed: {'no2_normalized': -9.577978, 'pm10_normalized': 0.07926312, 'so2_normalized': -3.174593, 'soot_normalized': 0.052926708}
# Raw:  {'pm10': 32.95, 'no2': 27.42, 'so2': 12.55, 'soot': 11.92}
# Transformed: {'no2_normalized': -5.2579784, 'pm10_normalized': 0.098091334, 'so2_normalized': -2.9745932, 'soot_normalized': 0.058239054}
# Raw:  {'pm10': 22.08, 'no2': 30.36, 'so2': 12.02, 'soot': 10.5}
# Transformed: {'no2_normalized': -2.317978, 'pm10_normalized': 0.057961382, 'so2_normalized': -3.504593, 'soot_normalized': 0.04426955}
# Raw:  {'pm10': 32.73, 'no2': 35.57, 'so2': 14.79, 'soot': 12.7}
# Transformed: {'no2_normalized': 2.8920212, 'pm10_normalized': 0.09727913, 'so2_normalized': -0.7345934, 'soot_normalized': 0.06591244}
# Raw:  {'pm10': 28.98, 'no2': 30.92, 'so2': 14.07, 'soot': 13.15}
# Transformed: {'no2_normalized': -1.7579784, 'pm10_normalized': 0.08343485, 'so2_normalized': -1.4545937, 'soot_normalized': 0.07033939}
# Raw:  {'pm10': 42.05, 'no2': 34.51, 'so2': 15.36, 'soot': 13.18}
# Transformed: {'no2_normalized': 1.8320198, 'pm10_normalized': 0.13168678, 'so2_normalized': -0.1645937, 'soot_normalized': 0.07063453}
# Raw:  {'pm10': 58.78, 'no2': 45.75, 'so2': 14.98, 'soot': 22.3}
# Transformed: {'no2_normalized': 13.0720215, 'pm10_normalized': 0.19345072, 'so2_normalized': -0.5445938, 'soot_normalized': 0.16035414}
# Raw:  {'pm10': 63.48, 'no2': 51.06, 'so2': 15.23, 'soot': 25.33}
# Transformed: {'no2_normalized': 18.382023, 'pm10_normalized': 0.21080223, 'so2_normalized': -0.2945938, 'soot_normalized': 0.19016232}
# Raw:  {'pm10': 57.1, 'no2': 42.83, 'so2': 15.44, 'soot': 27.76}
# Transformed: {'no2_normalized': 10.152023, 'pm10_normalized': 0.18724848, 'so2_normalized': -0.08459377, 'soot_normalized': 0.21406788}
# Raw:  {'pm10': 34.05, 'no2': 38.46, 'so2': 13.78, 'soot': 19.68}
# Transformed: {'no2_normalized': 5.7820206, 'pm10_normalized': 0.10215232, 'so2_normalized': -1.7445936, 'soot_normalized': 0.13457943}
# Raw:  {'pm10': 36.8, 'no2': 40.8, 'so2': 13.79, 'soot': 18.8}
# Transformed: {'no2_normalized': 8.122021, 'pm10_normalized': 0.11230479, 'so2_normalized': -1.7345934, 'soot_normalized': 0.12592226}
# Raw:  {'pm10': 35.15, 'no2': 34.6, 'so2': 12.44, 'soot': 18.1}
# Transformed: {'no2_normalized': 1.92202, 'pm10_normalized': 0.10621332, 'so2_normalized': -3.0845938, 'soot_normalized': 0.11903591}
# Raw:  {'pm10': 49.28, 'no2': 39.76, 'so2': 16.46, 'soot': 18.62}
# Transformed: {'no2_normalized': 7.08202, 'pm10_normalized': 0.15837854, 'so2_normalized': 0.93540573, 'soot_normalized': 0.1241515}
# Raw:  {'pm10': 66.23, 'no2': 38.92, 'so2': 15.99, 'soot': 24.0}
# Transformed: {'no2_normalized': 6.2420197, 'pm10_normalized': 0.2209547, 'so2_normalized': 0.46540642, 'soot_normalized': 0.1770782}
# Raw:  {'pm10': 51.9, 'no2': 29.95, 'so2': 12.58, 'soot': 17.11}
# Transformed: {'no2_normalized': -2.7279778, 'pm10_normalized': 0.1680511, 'so2_normalized': -2.9445934, 'soot_normalized': 0.109296605}
# Raw:  {'pm10': 41.4, 'no2': 20.78, 'so2': 16.75, 'soot': 16.29}
# Transformed: {'no2_normalized': -11.897978, 'pm10_normalized': 0.12928711, 'so2_normalized': 1.2254066, 'soot_normalized': 0.10122971}
# Raw:  {'pm10': 26.83, 'no2': 26.44, 'so2': 15.29, 'soot': 11.27}
# Transformed: {'no2_normalized': -6.237978, 'pm10_normalized': 0.07549747, 'so2_normalized': -0.23459339, 'soot_normalized': 0.051844567}
# Raw:  {'pm10': 22.47, 'no2': 26.38, 'so2': 16.08, 'soot': 8.19}
# Transformed: {'no2_normalized': -6.2979794, 'pm10_normalized': 0.059401188, 'so2_normalized': 0.5554066, 'soot_normalized': 0.02154451}
# Raw:  {'pm10': 17.87, 'no2': 27.9, 'so2': 16.79, 'soot': 9.55}
# Transformed: {'no2_normalized': -4.777979, 'pm10_normalized': 0.042418875, 'so2_normalized': 1.2654076, 'soot_normalized': 0.03492376}
# Raw:  {'pm10': 21.73, 'no2': 27.23, 'so2': 18.79, 'soot': 8.49}
# Transformed: {'no2_normalized': -5.447979, 'pm10_normalized': 0.05666925, 'so2_normalized': 3.2654076, 'soot_normalized': 0.024495816}
# Raw:  {'pm10': 22.07, 'no2': 27.29, 'so2': 14.36, 'soot': 11.04}
# Transformed: {'no2_normalized': -5.3879776, 'pm10_normalized': 0.057924464, 'so2_normalized': -1.1645937, 'soot_normalized': 0.049581897}
# Raw:  {'pm10': 53.3, 'no2': 34.32, 'so2': 15.87, 'soot': 12.51}
# Transformed: {'no2_normalized': 1.6420212, 'pm10_normalized': 0.17321962, 'so2_normalized': 0.34540653, 'soot_normalized': 0.06404328}
# Raw:  {'pm10': 72.27, 'no2': 32.79, 'so2': 19.79, 'soot': 14.8}
# Transformed: {'no2_normalized': 0.1120224, 'pm10_normalized': 0.24325322, 'so2_normalized': 4.2654076, 'soot_normalized': 0.08657157}
# Raw:  {'pm10': 35.07, 'no2': 25.75, 'so2': 15.19, 'soot': 12.5}
# Transformed: {'no2_normalized': -6.9279785, 'pm10_normalized': 0.10591796, 'so2_normalized': -0.33459377, 'soot_normalized': 0.063944906}
# Raw:  {'pm10': 30.7, 'no2': 33.26, 'so2': 14.51, 'soot': 14.18}
# Transformed: {'no2_normalized': 0.5820198, 'pm10_normalized': 0.089784764, 'so2_normalized': -1.0145931, 'soot_normalized': 0.08047221}
# Raw:  {'pm10': 59.2, 'no2': 37.4, 'so2': 27.18, 'soot': 20.77}
# Transformed: {'no2_normalized': 4.722023, 'pm10_normalized': 0.19500129, 'so2_normalized': 11.655407, 'soot_normalized': 0.1453025}
# Raw:  {'pm10': 89.33, 'no2': 47.61, 'so2': 23.2, 'soot': 25.04}
# Transformed: {'no2_normalized': 14.932022, 'pm10_normalized': 0.3062355, 'so2_normalized': 7.6754074, 'soot_normalized': 0.1873094}
# Raw:  {'pm10': 78.7, 'no2': 55.61, 'so2': 21.38, 'soot': 27.87}
# Transformed: {'no2_normalized': 22.932022, 'pm10_normalized': 0.26699156, 'so2_normalized': 5.855406, 'soot_normalized': 0.21515001}
# Raw:  {'pm10': 177.1, 'no2': 85.79, 'so2': 23.24, 'soot': 36.75}
# Transformed: {'no2_normalized': 53.112022, 'pm10_normalized': 0.6302654, 'so2_normalized': 7.7154064, 'soot_normalized': 0.3025086}
# Raw:  {'pm10': 190.23, 'no2': 89.32, 'so2': 25.1, 'soot': 34.97}
# Transformed: {'no2_normalized': 56.64202, 'pm10_normalized': 0.67873883, 'so2_normalized': 9.575407, 'soot_normalized': 0.28499752}
# Raw:  {'pm10': 142.83, 'no2': 58.59, 'so2': 21.36, 'soot': 23.35}
# Transformed: {'no2_normalized': 25.912022, 'pm10_normalized': 0.50374717, 'so2_normalized': 5.8354073, 'soot_normalized': 0.17068371}
# Raw:  {'pm10': 88.77, 'no2': 42.78, 'so2': 19.86, 'soot': 23.85}
# Transformed: {'no2_normalized': 10.10202, 'pm10_normalized': 0.30416805, 'so2_normalized': 4.3354073, 'soot_normalized': 0.17560256}
# Raw:  {'pm10': 63.73, 'no2': 52.96, 'so2': 19.28, 'soot': 26.09}
# Transformed: {'no2_normalized': 20.28202, 'pm10_normalized': 0.21172518, 'so2_normalized': 3.7554073, 'soot_normalized': 0.19763894}
# Raw:  {'pm10': 114.83, 'no2': 82.11, 'so2': 25.87, 'soot': 29.71}
# Transformed: {'no2_normalized': 49.432022, 'pm10_normalized': 0.4003766, 'so2_normalized': 10.3454075, 'soot_normalized': 0.23325133}
# Raw:  {'pm10': 75.4, 'no2': 61.62, 'so2': 20.27, 'soot': 24.95}
# Transformed: {'no2_normalized': 28.94202, 'pm10_normalized': 0.2548086, 'so2_normalized': 4.745407, 'soot_normalized': 0.186424}
# Raw:  {'pm10': 67.47, 'no2': 39.94, 'so2': 19.6, 'soot': 19.67}
# Transformed: {'no2_normalized': 7.26202, 'pm10_normalized': 0.22553255, 'so2_normalized': 4.075407, 'soot_normalized': 0.13448106}
# Raw:  {'pm10': 62.93, 'no2': 71.05, 'so2': 25.36, 'soot': 19.86}
# Transformed: {'no2_normalized': 38.372025, 'pm10_normalized': 0.20877174, 'so2_normalized': 9.835407, 'soot_normalized': 0.13635021}
# Raw:  {'pm10': 114.03, 'no2': 86.51, 'so2': 30.76, 'soot': 29.9}
# Transformed: {'no2_normalized': 53.832024, 'pm10_normalized': 0.39742312, 'so2_normalized': 15.235407, 'soot_normalized': 0.23512049}
# Raw:  {'pm10': 178.07, 'no2': 106.03, 'so2': 33.76, 'soot': 43.22}
# Transformed: {'no2_normalized': 73.35202, 'pm10_normalized': 0.6338465, 'so2_normalized': 18.235405, 'soot_normalized': 0.36615837}
# Raw:  {'pm10': 98.0, 'no2': 82.28, 'so2': 27.73, 'soot': 31.5}
# Transformed: {'no2_normalized': 49.60202, 'pm10_normalized': 0.33824345, 'so2_normalized': 12.205406, 'soot_normalized': 0.25086078}
# Raw:  {'pm10': 24.07, 'no2': 44.24, 'so2': 15.76, 'soot': 16.46}
# Transformed: {'no2_normalized': 11.562023, 'pm10_normalized': 0.06530808, 'so2_normalized': 0.23540688, 'soot_normalized': 0.1029021}
# Raw:  {'pm10': 24.03, 'no2': 42.27, 'so2': 18.57, 'soot': 14.21}
# Transformed: {'no2_normalized': 9.592022, 'pm10_normalized': 0.065160416, 'so2_normalized': 3.0454063, 'soot_normalized': 0.08076733}
# Raw:  {'pm10': 47.97, 'no2': 31.57, 'so2': 15.66, 'soot': 14.01}
# Transformed: {'no2_normalized': -1.1079788, 'pm10_normalized': 0.1535423, 'so2_normalized': 0.1354065, 'soot_normalized': 0.0787998}
